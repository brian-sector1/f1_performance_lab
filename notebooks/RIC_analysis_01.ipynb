# %%
import fastf1
event = fastf1.get_event(2018, "Monaco")
event
# Out:
# RoundNumber                                            6
# Country                                           Monaco
# Location                                     Monte Carlo
# OfficialEventName    FORMULA 1 GRAND PRIX DE MONACO 2018
# EventDate                            2018-05-27 00:00:00
# EventName                              Monaco Grand Prix
# EventFormat                                 conventional
# Session1                                      Practice 1
# Session1Date                   2018-05-24 11:00:00+02:00
# Session1DateUtc                      2018-05-24 09:00:00
# Session2                                      Practice 2
# Session2Date                   2018-05-24 15:00:00+02:00
# Session2DateUtc                      2018-05-24 13:00:00
# Session3                                      Practice 3
# Session3Date                   2018-05-26 12:00:00+02:00
# Session3DateUtc                      2018-05-26 10:00:00
# ...

# %%
session = fastf1.get_session(2018, "Monaco", 'Q')
# the race that max verstappen destroyed his car in practice
session.load()
session.results
session.results.iloc[10:20].loc[:, ['Abbreviation']]
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 33
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 33)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
session.laps.iloc[30:35]
# Out:
#                      Time Driver DriverNumber                LapTime  \
# 30 0 days 00:54:48.838000    VET            5                    NaT
# 31 0 days 00:56:22.933000    VET            5 0 days 00:01:34.095000
# 32 0 days 00:57:34.196000    VET            5 0 days 00:01:11.263000
# 33 0 days 01:00:56.605000    VET            5                    NaT
# 34 0 days 01:02:20.809000    VET            5 0 days 00:01:24.204000
#
#     LapNumber  Stint             PitOutTime              PitInTime  \
# 30       14.0    3.0                    NaT 0 days 00:46:13.860000
# 31       15.0    4.0 0 days 00:54:49.540000                    NaT
# 32       16.0    4.0                    NaT                    NaT
# 33       17.0    4.0                    NaT 0 days 00:58:48.504000
# 34       18.0    5.0 0 days 01:00:57.301000                    NaT
#
#               Sector1Time            Sector2Time  ... FreshTyre     Team  \
# ...

# %%
fastest_lap = session.laps.pick_fastest()
print(fastest_lap['LapTime'])
print(fastest_lap['Driver'])
# Out:
# 0 days 00:01:10.810000
# RIC
